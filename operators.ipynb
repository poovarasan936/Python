# %%
a=6
b=5
print("Addition:",a+b)
print("Subtraction:",a-b)
print("Multiplication:",a*b)
print("Division:",a/b)
print("Floor Division:",a//b)
print("Modulus:",a%b)
print("Exponentiation:",a**b)
# Out:
# Addition: 11
# Subtraction: 1
# Multiplication: 30
# Division: 1.2
# Floor Division: 1
# Modulus: 1
# Exponentiation: 7776

# %%
a=11
b=12
c=11
print("Equality:",a==b)
print("Not Equality:",a!=b)
print("Equality:",a==c)
print("Greater Than:",a>b)
print("Less Than:",a<c)
print("Greater Than or Equal:",a>=c)
print("Less Than or Equal:",a<=b)
# Out:
# Equality: False
# Not Equality: True
# Equality: True
# Greater Than: False
# Less Than: False
# Greater Than or Equal: True
# Less Than or Equal: True

# %%
a=50
b=46
c=60
print("Logical AND:",a>b and a>c)
print("Logical OR:",a>b or a>c)
print("Logical NOT:",not a<b)
print("Logical Not:",a<b and not a>c)
# Out:
# Logical AND: False
# Logical OR: True
# Logical NOT: True
# Logical Not: False

# %%
a=5
b=6
print(a)
a*=2
print(a)
b+=a
print(b)
# Out:
# 5
# 10
# 16

# %%
a=[1,3,52,6,23]
b=a
c=[1,3,52,6,23]
print(a is b)#Here a is b is true because both a and b are pointing to the same object in memory
print (a is c)#Here a is c is false because even though the elements in a and c are same , the a is a different object and c is a different object
print(c is a)# Here C is a is false because eventhoue the elements in c and a are same , the a is a different object and c is a different object  but b=a is true because a and b are same objects
print(c is not a)
# Out:
# True
# False
# False
# True

# %%
a=[1,2,3,4,5,6]
b=[25,3,52,3]
c=[a]
print( 4 in a)
print(a in c)
print(52 in b)
print(5 not in a)
# Out:
# True
# True
# True
# False

# %%
a=4
b=5
print("And:", a&b)#Hera a&b is 4 because in binary 4 is 100 and 5 is 101 and the result of 100 & 101 is 100 which is 4 in decimal
print("Or:", a|b)#Here a|b is 5 because in binary 4 is 100 and 5 is 101 and the result of 100 | 101 is 101 which is 5 in decimal
print("Xor:",a^b)#Here a^b is 1 because in binary 4 is 100 and 5 is 101 and the result of 100 ^ 101 is 001 which is 1 in decimal
print("Nand:",a%~b)#Here a%~b is 4 because in binary 4 is 100 and 5 is 101 and the result of ~5 is -6 in decimal and the result of 4 % -6 is 4 because when we divide 4 by -6 the quotient is 0 and the remainder is 4
print(~-6)#Here ~-6 is 5 because in binary -6 is represented as the two's complement of 6 which is 11111111111111111111111111111010 and the result of ~-6 is 00000000000000000000000000000101 which is 5 in decimal
# Out:
# And: 4
# Or: 5
# Xor: 1
# Nand: -2
# 5

# %%
a="The world is Beautiful"
print(a[4:9])
print(a[:5])
print(a[7:])
print(a[-15:-9])
print(a[::-1])# Inverted or Reverse String
# Out:
# world
# The w
# ld is Beautiful
# ld is
# lufituaeB si dlrow ehT

# %%
a="The sky is mesmerizing "
print("Uppercase:",a.upper())
print("Lowercase:",a.lower())
print(a.strip())#removes spacing in the start and end of a string
print(a.replace("mesmerizing","beautiful"))#It helps to replace the vaues in the string
print(a.split())#To split the string based on the spaces/
b="This is unethical , please be mindful of your actions"
print(b.split(','))#Split the string based onthe ,
# Out:
# Uppercase: THE SKY IS MESMERIZING
# Lowercase: the sky is mesmerizing
# The sky is mesmerizing
# The sky is beautiful
# ['The', 'sky', 'is', 'mesmerizing']
# ['This is unethical ', ' please be mindful of your actions']
