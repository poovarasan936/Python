# %%
a=(1,3,5,234,632,34,643)
b=("dhoni","virat","rohit","ruturaj")
c=("English","Tamil","Mathematics","science")
print(a)
print(b)
print(c)
print(type(a))
print(type(b))
print(type(b))
# Out:
# (1, 3, 5, 234, 632, 34, 643)
# ('dhoni', 'virat', 'rohit', 'ruturaj')
# ('English', 'Tamil', 'Mathematics', 'science')
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %%
a=(3,5,74,6,8,4,7,4,6,5,8)
print(a)
b=a[1:6]
print(b)
c=a[-8:-2]
print(c)
# Out:
# (3, 5, 74, 6, 8, 4, 7, 4, 6, 5, 8)
# (5, 74, 6, 8, 4)
# (6, 8, 4, 7, 4, 6)

# %%
x=("virat","rohit","dhoni")
y=list(x)
print(y)
y[0]="kholi"
print(y)
x=tuple(y)
print(x)
# Out:
# ['virat', 'rohit', 'dhoni']
# ['kholi', 'rohit', 'dhoni']
# ('kholi', 'rohit', 'dhoni')

# %%
x=("virat","Dhoni","Rohit")
y=list(x)
y.append("ruturaj")
x=tuple(y)
print(x)
# Out:
# ('virat', 'Dhoni', 'Rohit', 'ruturaj')

# %%
x=("virat","Dhoni","Rohit")
print("Before Removal:",x)
y=list(x)
y.remove("virat")
x=tuple(y)
print("After Removal:",x)
# Out:
# Before Removal: ('virat', 'Dhoni', 'Rohit')
# After Removal: ('Dhoni', 'Rohit')

# %%
#count in tuple
var1=(1,2,4,3,1,53,234)
var2=var1.count(2)
print(var2)
#index in tuple
print(var1.index(4))
# Out:
# 1
# 2

# %%
a=("virat","rohit","dhoni","hardik")#packing of tuple
(b,c,d,e)=a#unpacking of tuple
print(b)
print(c)
print(d)
print(e)
# Out:
# virat
# rohit
# dhoni
# hardik
